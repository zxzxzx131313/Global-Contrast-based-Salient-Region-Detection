# %% [markdown]
# <a href="https://colab.research.google.com/github/zxzxzx131313/Global-Contrast-based-Salient-Region-Detection/blob/master/020622_Exercise1_StyleGAN2_Colab_Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Training StyleGAN2 on Colab
# If it were me I’d sign up for Colab Pro ($10/month) to get a couple extra hours of training time in per session. The notebook is broken up into a couple of parts the first is training the network. Then testing it with a latent walk. Before we get into too many details of the process - here are the main steps of generating the walk.
# - Get the StyleGAN2 repo so that we can use the scripts from it
# - Get the training dataset, this is what you scrape and stuff
# - Then we point the model from the repo and train a model
# - Lastly we generate images which are a walk in this latent space

# %% [markdown]
# ##Mounting Google Drive
# So connect up to your google drive so that you can download the repo directly into your drive.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ##Install the repo
# **Only do this for the first time ever setting this up!**
#
# If this is your first time ever running this notebook, you’ll want to install my fork of StyleGAN2 to your Drive account. Make sure you have ample space on your Drive (I’d say at least 50GB). This will install the repo and add some dependecies (like transferring from FFHQ the first time).
#
# Every time after your first use of this notebook you’ll want to skip this cell and run the cell after this.

# %%
#SKIP this if you already have a stylegan2 folder in your google drive
# this makes a folder 
# %cd /content/drive/My/Drive/
# !mkdir stylegan2-colab
# then we get into the folder
# %cd stylegan2-colab/
# this clones the repository 
# !git clone https://github.com/dvschultz/stylegan2
# then we go into the repo
# %cd stylegan2
# then we make a folder called "pkl"
# !mkdir pkl
# %cd pkl
# the gdown commands downloads a file and the ID is whats specified
# !gdown --id 1JLqXE5bGZnlu2BkbLPD5_ZxoO3Nz-AvF #inception: https://drive.google.com/open?id=1JLqXE5bGZnlu2BkbLPD5_ZxoO3Nz-AvF
# %cd ../
# then make a results drirectory
# !mkdir results
# and under results we would make and navigate to a folder called 00001-pretrained
# !mkdir results/00001-pretrained
# %cd results/00001-pretrained
# download that too! 
# !gdown --id 1UlDmJVLLnBD9SnLSMXeiZRO6g-OMQCA_
# !mv stylegan2-ffhq-config-f.pkl network-snapshot-10000.pkl
# %cd ../../
# lastly make a folder called datasets
# %mkdir datasets
# Out:
# [Errno 2] No such file or directory: '/content/drive/My/Drive/'
# /content/stylegan2-colab/stylegan2
# /content/stylegan2-colab/stylegan2/stylegan2-colab
# Cloning into 'stylegan2'...
# remote: Enumerating objects: 552, done.
# remote: Total 552 (delta 0), reused 0 (delta 0), pack-reused 552
# Receiving objects: 100% (552/552), 22.47 MiB | 32.64 MiB/s, done.
# Resolving deltas: 100% (285/285), done.
# /content/stylegan2-colab/stylegan2/stylegan2-colab/stylegan2
# /content/stylegan2-colab/stylegan2/stylegan2-colab/stylegan2/pkl
# Downloading...
# From: https://drive.google.com/uc?id=1JLqXE5bGZnlu2BkbLPD5_ZxoO3Nz-AvF
# To: /content/stylegan2-colab/stylegan2/stylegan2-colab/stylegan2/pkl/inception_v3_features.pkl
# 100% 87.3M/87.3M [00:00<00:00, 166MB/s]
# /content/stylegan2-colab/stylegan2/stylegan2-colab/stylegan2
# /content/stylegan2-colab/stylegan2/stylegan2-colab/stylegan2/results/00001-pretrained
# Downloading...
# From: https://drive.google.com/uc?id=1UlDmJVLLnBD9SnLSMXeiZRO6g-OMQCA_
# To: /content/stylegan2-colab/stylegan2/stylegan2-colab/stylegan2/results/00001-pretrained/stylegan2-ffhq-config-f.pkl
# 100% 382M/382M [00:01<00:00, 257MB/s]
# /content/stylegan2-colab/stylegan2/stylegan2-colab/stylegan2

# %% [markdown]
# ##Picking up from a previous session
# If you already have the StyleGAN2 repo installed in Drive skip the above cell and run the following. This will make sure you have the latest version in case I make updates.

# %%
#USE this if you already have a stylegan2 folder in google drive
# %cd /content/drive/My\ Drive/stylegan2-colab/stylegan2
# !git pull
# Out:
# /content/drive/My Drive/stylegan2-colab/stylegan2
# Already up to date.

# %% [markdown]
# ##Make sure Tensorflow 1.15 is set
# Colab now defaults to Tensorflow 2. Make sure you run this cell to reset it to TF1.

# %%
# %tensorflow_version 1.x

# %% [markdown]
# ##Converting your dataset
# StyleGAN requires you to convert your standard jpg or png images into a new format (.tfrecords).
#
# I’ve seen some recommendations to run this command every time you restart your Colab machine. I think if you ahve a small-ish dataset (< 2000 images) that’s probably unnecessary.
#
# I recommend you upload your dataset to Google Drive and copy its path from the Drive folder in Colab and paste its path in the below cell.
#
# After the `create_from_images` argument you need to pass in two paths. The first path is where the .tfrecords files should be output (just edit the last part to have a unique name). The second path is to the directory of your images.

# %%
import os # this gives a nifty thing to list out directories 
os.listdir('/content/drive/MyDrive/Neural Bodies/Datasets/TA Meeting New Data set') # just make sure the directoy is right
# Out:
# ['Mug051.png',
#  'Mug055.png',
#  'Mug054.png',
#  'Mug056.png',
#  'Mug058.png',
#  'Mug057.png',
#  'Mug060.png',
#  'Mug059.png',
#  'Mug061.png',
#  'Mug062.png',
#  'Mug063.png',
#  'Mug065.png',
#  'Mug064.png',
#  'Mug066.png',
#  'Mug067.png',
#  'Mug068.png',
#  'Mug070.png',
#  'Mug069.png',
#  'Mug072.png',
#  'Mug071.png',
#  'Mug073.png',
#  'Mug074.png',
#  'Mug075.png',
#  'Mug077.png',
#  'Mug076.png',
#  'Mug079.png',
#  'Mug078.png',
#  'Mug081.png',
#  'Mug083.png',
#  'Mug082.png',
#  'Mug085.png',
#  'Mug084.png',
#  'Mug086.png',
#  'Mug088.png',
#  'Mug087.png',
#  'Mug090.png',
#  'Mug089.png',
#  'Mug091.png',
#  'Mug093.png',
#  'Mug092.png',
#  'Mug095.png',
#  'Mug096.png',
#  'Mug099.png',
#  'Mug102.png',
#  'Mug100.png',
#  'Mug103.png',
#  'Mug105.png',
#  'Mug104.png',
#  'Mug106.png',
#  'Mug107.png',
#  'Mug109.png',
#  'Mug110.png',
#  'Mug112.png',
#  'Mug113.png',
#  'Mug117.png',
#  'Mug115.png',
#  'Mug118.png',
#  'Mug119.png',
#  'Mug120.png',
#  'Mug121.png',
#  'Mug122.png',
#  'Mug124.png',
#  'Mug123.png',
#  'Mug125.png',
#  'Mug127.png',
#  'Mug126.png',
#  'Mug128.png',
#  'Mug129.png',
#  'Mug132.png',
#  'Mug130.png',
#  'Mug133.png',
#  'Mug135.png',
#  'Mug134.png',
#  'Mug137.png',
#  'Mug140.png',
#  'Mug139.png',
#  'Mug141.png',
#  'Mug142.png',
#  'Mug143.png',
#  'Mug145.png',
#  'Mug147.png',
#  'Mug149.png',
#  'Mug151.png',
#  'Mug150.png',
#  'Mug152.png',
#  'Mug154.png',
#  'Mug156.png',
#  'Mug157.png',
#  'Mug158.png',
#  'Mug159.png',
#  'Mug162.png',
#  'Mug161.png',
#  'Mug164.png',
#  'Mug165.png',
#  'Mug166.png',
#  'Mug167.png',
#  'Mug168.png',
#  'Mug169.png',
#  'Mug170.png',
#  'Mug171.png',
#  'Mug173.png',
#  'Mug174.png',
#  'Mug175.png',
#  'Mug176.png',
#  'Mug177.png',
#  'Mug178.png',
#  'Mug179.png',
#  'Mug182.png',
#  'Mug180.png',
#  'Mug184.png',
#  'Mug187.png',
#  'Mug188.png',
#  'Mug189.png',
#  'Mug190.png',
#  'Mug192.png',
#  'Mug193.png',
#  'Mug195.png',
#  'Mug196.png',
#  'Mug197.png',
#  'Mug198.png',
#  'Mug199.png',
#  'Mug200.png',
#  'Mug203.png',
#  'Mug206.png',
#  'Mug204.png',
#  'Mug209.png',
#  'Mug207.png',
#  'Mug211.png',
#  'Mug210.png',
#  'Mug213.png',
#  'Mug214.png',
#  'Mug216.png',
#  'Mug223.png',
#  'Mug217.png',
#  'Mug224.png',
#  'Mug226.png',
#  'Mug227.png',
#  'Mug232.png',
#  'Mug233.png',
#  'Mug236.png',
#  'Mug239.png',
#  'Mug237.png',
#  'Mug240.png',
#  'Mug243.png',
#  'Mug244.png',
#  'Mug245.png',
#  'Mug247.png',
#  'Mug256.png',
#  'Mug252.png',
#  'Mug257.png',
#  'Mug258.png',
#  'Mug259.png',
#  'Mug260.png',
#  'Mug262.png',
#  'Mug263.png',
#  'Mug265.png',
#  'Mug268.png',
#  'Mug266.png',
#  'Mug272.png',
#  'Mug274.png',
#  'Mug273.png',
#  'Mug278.png',
#  'Mug277.png',
#  'Mug281.png',
#  'Mug284.png',
#  'Mug285.png',
#  'Mug286.png',
#  'Mug290.png',
#  'Mug287.png',
#  'Mug294.png',
#  'Mug293.png',
#  'Mug299.png',
#  'Mug298.png',
#  'Mug300.png',
#  'Mug309.png',
#  'Mug306.png',
#  'Mug312.png',
#  'Mug311.png',
#  'Mug313.png',
#  'Mug318.png',
#  'Mug319.png',
#  'Mug321.png',
#  'Mug324.png',
#  'Mug329.png',
#  'Mug325.png',
#  'Mug330.png',
#  'Mug331.png',
#  'Mug335.png',
#  'Mug336.png',
#  'Mug337.png',
#  'Mug338.png',
#  'Mug339.png',
#  'Mug341.png',
#  'Mug343.png',
#  'Mug344.png',
#  'Mug349.png',
#  'Mug347.png',
#  'Mug351.png',
#  'Mug350.png',
#  'Mug353.png',
#  'Mug358.png',
#  'Mug357.png',
#  'Mug361.png',
#  'Mug362.png',
#  'Mug365.png',
#  'Mug370.png',
#  'Mug367.png',
#  'Mug371.png',
#  'Mug373.png',
#  'Mug376.png',
#  'Mug377.png',
#  'Mug381.png',
#  'Mug383.png',
#  'Mug382.png',
#  'Mug384.png',
#  'Mug386.png',
#  'Mug394.png',
#  'Mug387.png',
#  'Mug395.png',
#  'Mug396.png',
#  'Mug397.png',
#  'Mug400.png',
#  'Mug402.png',
#  'Mug405.png',
#  'Mug404.png',
#  'Mug408.png',
#  'Mug411.png',
#  'Mug410.png',
#  'Mug412.png',
#  'Mug415.png',
#  'Mug416.png',
#  'Mug421.png',
#  'Mug430.png',
#  'Mug424.png',
#  'Mug431.png',
#  'Mug434.png',
#  'Mug435.png',
#  'Mug436.png',
#  'Mug449.png',
#  'Mug457.png',
#  'Mug450.png',
#  'Mug461.png',
#  'Mug459.png',
#  'Mug463.png',
#  'Mug462.png',
#  'Mug465.png',
#  'Mug471.png',
#  'Mug466.png',
#  'Mug472.png',
#  'Mug476.png',
#  'Mug483.png',
#  'Mug480.png',
#  'Mug484.png',
#  'Mug485.png',
#  'Mug488.png',
#  'Mug490.png',
#  'Mug497.png',
#  'Mug491.png',
#  'Mug499.png',
#  'Mug501.png',
#  'Mug505.png',
#  'Mug503.png',
#  'Mug507.png',
#  'Mug511.png',
#  'Mug510.png',
#  'Mug512.png',
#  'Mug513.png',
#  'Mug515.png',
#  'Mug518.png',
#  'Mug521.png',
#  'Mug525.png',
#  'Mug522.png',
#  'Mug528.png',
#  'Mug527.png',
#  'Mug531.png',
#  'Mug529.png',
#  'Mug533.png',
#  'Mug535.png',
#  'Mug534.png',
#  'Mug539.png',
#  'Mug537.png',
#  'Mug545.png',
#  'Mug543.png',
#  'Mug546.png',
#  'Mug549.png',
#  'Mug552.png',
#  'Mug557.png',
#  'Mug555.png',
#  'Mug559.png',
#  'Mug560.png',
#  'Mug568.png',
#  'Mug571.png',
#  'Mug570.png',
#  'Mug572.png',
#  'Mug575.png',
#  'Mug573.png',
#  'Mug576.png',
#  'Mug577.png',
#  'Mug579.png',
#  'Mug580.png',
#  'Mug581.png',
#  'Mug582.png',
#  'Mug586.png',
#  'Mug587.png',
#  'Mug588.png',
#  'Mug592.png',
#  'Mug589.png',
#  'Mug593.png',
#  'Mug597.png',
#  'Mug604.png',
#  'Mug602.png',
#  'Mug605.png',
#  'Mug609.png',
#  'Mug608.png',
#  'Mug610.png',
#  'Mug611.png',
#  'Mug613.png',
#  'Mug614.png',
#  'Mug615.png',
#  'Mug616.png',
#  'Mug617.png',
#  'Mug619.png',
#  'Mug618.png',
#  'Mug620.png',
#  'Mug621.png',
#  'Mug622.png',
#  'Mug624.png',
#  'Mug623.png',
#  'Mug626.png',
#  'Mug625.png',
#  'Mug628.png',
#  'Mug627.png',
#  'Mug629.png',
#  'Mug630.png',
#  'Mug631.png',
#  'Mug633.png',
#  'Mug632.png',
#  'Mug634.png',
#  'Mug635.png',
#  'Mug636.png',
#  'Mug639.png',
#  'Mug641.png',
#  'Mug640.png',
#  'Mug643.png',
#  'Mug642.png',
#  'Mug644.png',
#  'Mug645.png',
#  'Mug646.png',
#  'Mug647.png',
#  'Mug648.png',
#  'Mug650.png',
#  'Mug649.png',
#  'Mug651.png',
#  'Mug652.png',
#  'Mug653.png',
#  'Mug654.png',
#  'Mug655.png',
#  'Mug656.png',
#  'Mug657.png',
#  'Mug658.png',
#  'Mug660.png',
#  'Mug659.png',
#  'Mug661.png',
#  'Mug662.png',
#  'Mug663.png',
#  'Mug664.png',
#  'Mug665.png',
#  'Mug666.png',
#  'Mug668.png',
#  'Mug669.png',
#  'Mug673.png',
#  'Mug671.png',
#  'Mug674.png',
#  'Mug676.png',
#  'Mug681.png',
#  'Mug678.png',
#  'Mug683.png',
#  'Mug685.png',
#  'Mug686.png',
#  'Mug687.png',
#  'Mug688.png',
#  'Mug689.png',
#  'Mug690.png',
#  'Mug691.png',
#  'Mug693.png',
#  'Mug694.png',
#  'Mug702.png',
#  'Mug703.png',
#  'Mug704.png',
#  'Mug708.png',
#  'Mug711.png',
#  'Mug716.png',
#  'Mug715.png',
#  'Mug717.png',
#  'Mug719.png',
#  'Mug718.png',
#  'Mug722.png',
#  'Mug720.png',
#  'Mug724.png',
#  'Mug723.png',
#  'Mug725.png',
#  'Mug729.png',
#  'Mug731.png',
#  'Mug733.png',
#  'Mug734.png',
#  'Mug735.png',
#  'Mug736.png',
#  'Mug737.png',
#  'Mug742.png',
#  'Mug743.png',
#  'Mug746.png',
#  'Mug744.png',
#  'Mug747.png',
#  'Mug748.png',
#  'Mug750.png',
#  'Donut (101).png',
#  'Donut (100).png',
#  'Donut (102).png',
#  'Donut (104).png',
#  'Donut (103).png',
#  'Donut (105).png',
#  'Donut (106).png',
#  'Donut (107).png',
#  'Donut (108).png',
#  'Donut (109).png',
#  'Donut (110).png',
#  'Donut (111).png',
#  'Donut (112).png',
#  'Donut (114).png',
#  'Donut (113).png',
#  'Donut (115).png',
#  'Donut (116).png',
#  'Donut (117).png',
#  'Donut (119).png',
#  'Donut (118).png',
#  'Donut (120).png',
#  'Donut (121).png',
#  'Donut (122).png',
#  'Donut (123).png',
#  'Donut (124).png',
#  'Donut (126).png',
#  'Donut (125).png',
#  'Donut (127).png',
#  'Donut (128).png',
#  'Donut (129).png',
#  'Donut (130).png',
#  'Donut (132).png',
#  'Donut (131).png',
#  'Donut (133).png',
#  'Donut (134).png',
#  'Donut (135).png',
#  'Donut (136).png',
#  'Donut (137).png',
#  'Donut (138).png',
#  'Donut (139).png',
#  'Donut (141).png',
#  'Donut (140).png',
#  'Donut (142).png',
#  'Donut (143).png',
#  'Donut (144).png',
#  'Donut (145).png',
#  'Donut (146).png',
#  'Donut (148).png',
#  'Donut (147).png',
#  'Donut (149).png',
#  'Donut (150).png',
#  'Donut (151).png',
#  'Donut (152).png',
#  'Donut (153).png',
#  'Donut (155).png',
#  'Donut (154).png',
#  'Donut (156).png',
#  'Donut (158).png',
#  'Donut (157).png',
#  'Donut (159).png',
#  'Donut (160).png',
#  'Donut (161).png',
#  'Donut (162).png',
#  'Donut (164).png',
#  'Donut (163).png',
#  'Donut (165).png',
#  'Donut (166).png',
#  'Donut (167).png',
#  'Donut (168).png',
#  'Donut (169).png',
#  'Donut (170).png',
#  'Donut (171).png',
#  'Donut (173).png',
#  'Donut (172).png',
#  'Donut (174).png',
#  'Donut (176).png',
#  'Donut (175).png',
#  'Donut (177).png',
#  'Donut (178).png',
#  'Donut (179).png',
#  'Donut (180).png',
#  'Donut (181).png',
#  'Donut (183).png',
#  'Donut (182).png',
#  'Donut (185).png',
#  'Donut (184).png',
#  'Donut (186).png',
#  'Donut (187).png',
#  'Donut (188).png',
#  'Donut (189).png',
#  'Donut (190).png',
#  'Donut (191).png',
#  'Donut (192).png',
#  'Donut (193).png',
#  'Donut (195).png',
#  'Donut (194).png',
#  'Donut (197).png',
#  'Donut (196).png',
#  'Donut (198).png',
#  'Donut (199).png',
#  'Donut (200).png',
#  'Donut (202).png',
#  'Donut (201).png',
#  'Donut (203).png',
#  'Donut (205).png',
#  'Donut (204).png',
#  'Donut (206).png',
#  'Donut (207).png',
#  'Donut (208).png',
#  'Donut (209).png',
#  'Donut (210).png',
#  'Donut (211).png',
#  'Donut (212).png',
#  'Donut (213).png',
#  'Donut (215).png',
#  'Donut (214).png',
#  'Donut (216).png',
#  'Donut (217).png',
#  'Donut (218).png',
#  'Donut (219).png',
#  'Donut (221).png',
#  'Donut (220).png',
#  'Donut (222).png',
#  'Donut (224).png',
#  'Donut (223).png',
#  'Donut (225).png',
#  'Donut (226).png',
#  'Donut (227).png',
#  'Donut (229).png',
#  'Donut (228).png',
#  'Donut (230).png',
#  'Donut (231).png',
#  'Donut (233).png',
#  'Donut (232).png',
#  'Donut (235).png',
#  'Donut (234).png',
#  'Donut (236).png',
#  'Donut (238).png',
#  'Donut (237).png',
#  'Donut (239).png',
#  'Donut (240).png',
#  'Donut (241).png',
#  'Donut (242).png',
#  'Donut (243).png',
#  'Donut (245).png',
#  'Donut (244).png',
#  'Donut (246).png',
#  'Donut (247).png',
#  'Donut (248).png',
#  'Donut (249).png',
#  'Donut (251).png',
#  'Donut (250).png',
#  'Donut (253).png',
#  'Donut (252).png',
#  'Donut (254).png',
#  'Donut (255).png',
#  'Donut (256).png',
#  'Donut (257).png',
#  'Donut (258).png',
#  'Donut (259).png',
#  'Donut (261).png',
#  'Donut (260).png',
#  'Donut (262).png',
#  'Donut (263).png',
#  'Donut (264).png',
#  'Donut (265).png',
#  'Donut (266).png',
#  'Donut (268).png',
#  'Donut (267).png',
#  'Donut (269).png',
#  'Donut (271).png',
#  'Donut (270).png',
#  'Donut (272).png',
#  'Donut (273).png',
#  'Donut (274).png',
#  'Donut (275).png',
#  'Donut (276).png',
#  'Donut (277).png',
#  'Donut (278).png',
#  'Donut (279).png',
#  'Donut (280).png',
#  'Donut (281).png',
#  'Donut (283).png',
#  'Donut (282).png',
#  'Donut (284).png',
#  'Donut (286).png',
#  'Donut (285).png',
#  'Donut (288).png',
#  'Donut (287).png',
#  'Donut (289).png',
#  'Donut (290).png',
#  'Donut (291).png',
#  'Donut (292).png',
#  'Donut (293).png',
#  'Donut (295).png',
#  'Donut (294).png',
#  'Donut (296).png',
#  'Donut (298).png',
#  'Donut (297).png',
#  'Donut (299).png',
#  'Donut (300).png',
#  'Donut (301).png',
#  'Donut (303).png',
#  'Donut (302).png',
#  'Donut (304).png',
#  'Donut (305).png',
#  'Donut (307).png',
#  'Donut (306).png',
#  'Donut (308).png',
#  'Donut (309).png',
#  'Donut (310).png',
#  'Donut (311).png',
#  'Donut (312).png',
#  'Donut (313).png',
#  'Donut (315).png',
#  'Donut (314).png',
#  'Donut (317).png',
#  'Donut (316).png',
#  'Donut (318).png',
#  'Donut (32).png',
#  'Donut (319).png',
#  'Donut (320).png',
#  'Donut (321).png',
#  'Donut (322).png',
#  'Donut (324).png',
#  'Donut (323).png',
#  'Donut (325).png',
#  'Donut (327).png',
#  'Donut (326).png',
#  'Donut (328).png',
#  'Donut (329).png',
#  'Donut (330).png',
#  'Donut (331).png',
#  'Donut (332).png',
#  'Donut (333).png',
#  'Donut (335).png',
#  'Donut (334).png',
#  'Donut (337).png',
#  'Donut (336).png',
#  'Donut (338).png',
#  'Donut (339).png',
#  'Donut (34).png',
#  'Donut (341).png',
#  'Donut (340).png',
#  'Donut (342).png',
#  'Donut (343).png',
#  'Donut (344).png',
#  'Donut (346).png',
#  'Donut (345).png',
#  'Donut (347).png',
#  'Donut (348).png',
#  'Donut (349).png',
#  'Donut (35).png',
#  'Donut (351).png',
#  'Donut (350).png',
#  'Donut (352).png',
#  'Donut (353).png',
#  'Donut (354).png',
#  'Donut (355).png',
#  'Donut (356).png',
#  'Donut (357).png',
#  'Donut (359).png',
#  'Donut (358).png',
#  'Donut (360).png',
#  'Donut (36).png',
#  'Donut (361).png',
#  'Donut (362).png',
#  'Donut (363).png',
#  'Donut (364).png',
#  'Donut (366).png',
#  'Donut (365).png',
#  'Donut (367).png',
#  'Donut (368).png',
#  'Donut (37).png',
#  'Donut (369).png',
#  'Donut (370).png',
#  'Donut (371).png',
#  'Donut (373).png',
#  'Donut (372).png',
#  'Donut (374).png',
#  'Donut (375).png',
#  'Donut (376).png',
#  'Donut (377).png',
#  'Donut (379).png',
#  'Donut (378).png',
#  'Donut (38).png',
#  'Donut (380).png',
#  'Donut (381).png',
#  'Donut (382).png',
#  'Donut (383).png',
#  'Donut (384).png',
#  'Donut (386).png',
#  'Donut (385).png',
#  'Donut (388).png',
#  'Donut (387).png',
#  'Donut (389).png',
#  'Donut (39).png',
#  'Donut (390).png',
#  'Donut (391).png',
#  'Donut (393).png',
#  'Donut (392).png',
#  'Donut (394).png',
#  'Donut (395).png',
#  'Donut (397).png',
#  'Donut (396).png',
#  'Donut (398).png',
#  'Donut (399).png',
#  'Donut (40).png',
#  'Donut (401).png',
#  'Donut (400).png',
#  'Donut (402).png',
#  'Donut (403).png',
#  'Donut (405).png',
#  'Donut (404).png',
#  'Donut (407).png',
#  'Donut (406).png',
#  'Donut (408).png',
#  'Donut (41).png',
#  'Donut (409).png',
#  'Donut (411).png',
#  'Donut (410).png',
#  'Donut (413).png',
#  'Donut (412).png',
#  'Donut (415).png',
#  'Donut (414).png',
#  'Donut (417).png',
#  'Donut (416).png',
#  'Donut (419).png',
#  'Donut (418).png',
#  'Donut (42).png',
#  'Donut (420).png',
#  'Donut (421).png',
#  'Donut (423).png',
#  'Donut (422).png',
#  'Donut (424).png',
#  'Donut (425).png',
#  'Donut (427).png',
#  'Donut (426).png',
#  'Donut (429).png',
#  'Donut (428).png',
#  'Donut (430).png',
#  'Donut (43).png',
#  'Donut (431).png',
#  'Donut (432).png',
#  'Donut (433).png',
#  'Donut (434).png',
#  'Donut (436).png',
#  'Donut (435).png',
#  'Donut (437).png',
#  'Donut (438).png',
#  'Donut (44).png',
#  'Donut (439).png',
#  'Donut (45).png',
#  'Donut (440).png',
#  'Donut (46).png',
#  'Donut (47).png',
#  'Donut (48).png',
#  'Donut (49).png',
#  'Donut (50).png',
#  'Donut (51).png',
#  'Donut (53).png',
#  'Donut (52).png',
#  'Donut (54).png',
#  'Donut (55).png',
#  'Donut (56).png',
#  'Donut (57).png',
#  'Donut (59).png',
#  'Donut (58).png',
#  'Donut (61).png',
#  'Donut (60).png',
#  'Donut (62).png',
#  'Donut (63).png',
#  'Donut (64).png',
#  'Donut (65).png',
#  'Donut (67).png',
#  'Donut (66).png',
#  'Donut (68).png',
#  'Donut (69).png',
#  'Donut (70).png',
#  'Donut (71).png',
#  'Donut (73).png',
#  'Donut (72).png',
#  'Donut (74).png',
#  'Donut (75).png',
#  'Donut (76).png',
#  'Donut (78).png',
#  'Donut (77).png',
#  'Donut (79).png',
#  'Donut (80).png',
#  'Donut (82).png',
#  'Donut (81).png',
#  'Donut (84).png',
#  'Donut (83).png',
#  'Donut (86).png',
#  'Donut (85).png',
#  'Donut (87).png',
#  'Donut (88).png',
#  'Donut (89).png',
#  'Donut (90).png',
#  'Donut (91).png',
#  'Donut (92).png',
#  'Donut (93).png',
#  'Donut (94).png',
#  'Donut (95).png',
#  'Donut (97).png',
#  'Donut (96).png',
#  'Donut (98).png',
#  'Donut (99).png',
#  '1 (1).png',
#  '1.png',
#  '154560_sv.png',
#  'Courtyards008.png',
#  'Courtyards009.png',
#  'Courtyards011.png',
#  'Courtyards010.png',
#  'Courtyards012.png',
#  'Courtyards013.png',
#  'Courtyards014.png',
#  'Courtyards017.png',
#  'Courtyards015.png',
#  'Courtyards018.png',
#  'Courtyards019.png',
#  'Courtyards022.png',
#  'Courtyards021.png',
#  'Courtyards024.png',
#  'Courtyards025.png',
#  'Courtyards026.png',
#  'Courtyards029.png',
#  'Courtyards028.png',
#  'Courtyards030.png',
#  'Courtyards031.png',
#  'Courtyards034.png',
#  'Courtyards035.png',
#  'Courtyards038.png',
#  'Courtyards040.png',
#  'Courtyards041.png',
#  'Courtyards043.png',
#  'Courtyards044.png',
#  'Courtyards046.png',
#  'Courtyards047.png',
#  'Courtyards048.png',
#  'Courtyards053.png',
#  'Courtyards052.png',
#  'Courtyards055.png',
#  'Courtyards057.png',
#  'Courtyards056.png',
#  'Courtyards060.png',
#  'Courtyards061.png',
#  'Courtyards067.png',
#  'Courtyards068.png',
#  'Courtyards073.png',
#  'Courtyards072.png',
#  'Courtyards074.png',
#  'Courtyards076.png',
#  'Courtyards075.png',
#  'Courtyards077.png',
#  'Courtyards080.png',
#  'Courtyards078.png',
#  'Courtyards081.png',
#  'Courtyards082.png',
#  'Courtyards085.png',
#  'Courtyards086.png',
#  'Courtyards089.png',
#  'Courtyards087.png',
#  'Courtyards095.png',
#  'Courtyards101.png',
#  'Courtyards103.png',
#  'Courtyards104.png',
#  'Courtyards105.png',
#  'Courtyards108.png',
#  'Courtyards109.png',
#  'Courtyards111.png',
#  'Courtyards112.png',
#  'Courtyards116.png',
#  'Courtyards118.png',
#  'Courtyards123.png',
#  'Courtyards126.png',
#  'Courtyards133.png',
#  'Courtyards132.png',
#  'Courtyards135.png',
#  'Courtyards140.png',
#  'Courtyards138.png',
#  'Courtyards141.png',
#  'Courtyards142.png',
#  'Courtyards143.png',
#  'Courtyards146.png',
#  'Courtyards149.png',
#  'Courtyards148.png',
#  'Courtyards152.png',
#  'Courtyards155.png',
#  'Courtyards156.png',
#  'Courtyards158.png',
#  'Courtyards160.png',
#  'Courtyards165.png',
#  'Courtyards172.png',
#  'Courtyards182.png',
#  'Courtyards186.png',
#  'Courtyards192.png',
#  'Courtyards193.png',
#  'Courtyards203.png',
#  'Courtyards204.png',
#  'Courtyards208.png',
#  'Courtyards212.png',
#  'Courtyards217.png',
#  'Courtyards219.png',
#  'Courtyards228.png',
#  'Courtyards225.png',
#  'Courtyards235.png',
#  'Courtyards237.png',
#  'Courtyards240.png',
#  'Courtyards239.png',
#  'Courtyards241.png',
#  'Courtyards242.png',
#  'Courtyards244.png',
#  'Courtyards246.png',
#  'Courtyards248.png',
#  'Courtyards249.png',
#  'Courtyards251.png',
#  'Courtyards253.png',
#  'Courtyards254.png',
#  'Courtyards256.png',
#  'Courtyards262.png',
#  'Courtyards273.png',
#  'Courtyards283.png',
#  'Courtyards288.png',
#  'Courtyards291.png',
#  'Courtyards304.png',
#  'Courtyards305.png',
#  'Courtyards308.png',
#  'Courtyards312.png',
#  'Courtyards315.png',
#  'Courtyards316.png',
#  'Courtyards317.png',
#  'Courtyards318.png',
#  'Courtyards321.png',
#  'Courtyards320.png',
#  'Courtyards323.png',
#  'Courtyards327.png',
#  'Courtyards325.png',
#  'Courtyards328.png',
#  'Courtyards332.png',
#  'Courtyards331.png',
#  'Courtyards334.png',
#  'Courtyards339.png',
#  'Courtyards336.png',
#  'Courtyards341.png',
#  'Courtyards345.png',
#  'Courtyards349.png',
#  'Courtyards347.png',
#  'Courtyards352.png',
#  'Courtyards355.png',
#  'Courtyards358.png',
#  'Courtyards361.png',
#  'Courtyards366.png',
#  'Courtyards363.png',
#  'Courtyards369.png',
#  'Courtyards370.png',
#  'Courtyards373.png',
#  'Courtyards371.png',
#  'Courtyards374.png',
#  'Courtyards375.png',
#  'Courtyards376.png',
#  'Courtyards379.png',
#  'Courtyards378.png',
#  'Courtyards381.png',
#  'Courtyards383.png',
#  'Courtyards384.png',
#  'Courtyards392.png',
#  'Courtyards394.png',
#  'Courtyards395.png',
#  'Courtyards397.png',
#  'Courtyards398.png',
#  'Courtyards400.png',
#  'Courtyards408.png',
#  'Courtyards406.png',
#  'Courtyards409.png',
#  'Courtyards411.png',
#  'Courtyards413.png',
#  'download.png',
#  'fffd879eb1c0f4e69675e24af9870905.png',
#  'ef3b6a884261afbdcdb2fae6b53d80dd--masjid-islamic-architecture.png',
#  'gangtey-goemba_plan.png',
#  'plan.png',
#  'tipologia-madrasas-02-ince-minareli-madrasa-planta.png',
#  'Tunisia, Soussa --Ribat-fortified monastery-8.png',
#  ...]

# %%
# %cd /content/drive/MyDrive/stylegan2-colab/stylegan2
# %pwd
# Out:
# /content/drive/MyDrive/stylegan2-colab/stylegan2
# '/content/drive/MyDrive/stylegan2-colab/stylegan2'

# %%
#2nd argument is where to put your tfrecords files
#3rd should point at your image dataset
#so an argument looks like this 
#python dataset_tool.py (the python file) create_from_images (the function) ./datasets/hybrid-512 (the place to dump the TF files) 
# !python dataset_tool.py create_from_images '/content/drive/MyDrive/stylegan2-colab/stylegan2/datasets/NB_test1' '/content/drive/MyDrive/Neural Bodies/Datasets/TA_Meeting_New_Data_set' #Drive/beauxart/01-data/210122-plansectelev-512-stylegan
# Out:
# Loading images from "/content/drive/MyDrive/Neural Bodies/Datasets/TA_Meeting_New_Data_set"
# Error: Input image resolution must be a power-of-two

# %% [markdown]
# ##Training
# Note: this will require you to restart your Colab machine every 8–16 hours. You’ve been warned!
#
# This library is set up to automatically find your latest .pkl file so it should keep re-training and making progress.
#
# ##Training Options
# `--dataset`
#
# This should be the name you used in the first path when converting your dataset.
#
# `--mirror-augment`
#
# Using this option loads some images at random mirrored horizontally (left-to-right). This might help if you have a very small dataset.
#
# `--metrics`
#
# METRICS DON’T MATTER. It’s art! Use your eyes. Set `--metrics=None` and live your life.
#
# If you must use metrics, you have a few options. `fid50k`, the default, uses Frechet Inception Distance score. It’s what was used in StyleGAN1 and what most people know. It’s fine for images of animals and things, but it’s not great. `ppl_wend` is what StyleGAN2 prefers and claims to be more accurate. There are a bunch of other options but I’d recommend you stick with those. Note that both of these take 30–45minutes to run every time it runs so that cuts into your training time in Colab.

# %%
# !pip install numpy==1.19.5 # since we are using an older version of tensorflow -- if the cell after this ones fails run this one.
# Out:
# Requirement already satisfied: numpy==1.19.5 in /usr/local/lib/python3.7/dist-packages (1.19.5)

# %%
# !python run_training.py --num-gpus=1 --data-dir=./datasets --config=config-f --dataset=hybrid-512 --mirror-augment=false --metrics=None
# Out:
# Local submit - run_dir: results/00002-stylegan2-hybrid-512-1gpu-config-f
# dnnlib: Running training.training_loop.training_loop() on localhost...
# Streaming data using training.dataset.TFRecordDataset...
# Traceback (most recent call last):
#   File "run_training.py", line 202, in <module>
#     main()
#   File "run_training.py", line 197, in main
#     run(**vars(args))
#   File "run_training.py", line 128, in run
#     dnnlib.submit_run(**kwargs)
#   File "/content/drive/MyDrive/stylegan2-colab/stylegan2/dnnlib/submission/submit.py", line 343, in submit_run
#     return farm.submit(submit_config, host_run_dir)
#   File "/content/drive/MyDrive/stylegan2-colab/stylegan2/dnnlib/submission/internal/local.py", line 22, in submit
#     return run_wrapper(submit_config)
#   File "/content/drive/MyDrive/stylegan2-colab/stylegan2/dnnlib/submission/submit.py", line 280, in run_wrapper
#     run_func_obj(**submit_config.run_func_kwargs)
#   File "/content/drive/MyDrive/stylegan2-colab/stylegan2/training/training_loop.py", line 142, in training_loop
#     training_set = dataset.load_dataset(data_dir=dnnlib.convert_path(data_dir), verbose=True, **dataset_args)
#   File "/content/drive/MyDrive/stylegan2-colab/stylegan2/training/dataset.py", line 192, in load_dataset
#     dataset = dnnlib.util.get_obj_by_name(class_name)(**kwargs)
#   File "/content/drive/MyDrive/stylegan2-colab/stylegan2/training/dataset.py", line 53, in __init__
#     assert os.path.isdir(self.tfrecord_dir)
# AssertionError

# %% [markdown]
# Once running, your training files will show up in the results folder.

# %% [markdown]
# #Testing the model (generating images)
# The following command will generate 55 sample images from the model.
#
# ##Options
# `--network`
#
# Make sure the `--network` argument points to your .pkl file. (My preferred method is to right click on the file in the Files pane to your left and choose `Copy Path`, then paste that into the argument after the `=` sign).
#
# `--seeds`
#
# This allows you to choose random seeds from the model. Remember that our input to StyleGAN is a 512-dimensional array. These seeds will generate those 512 values. Each seed will generate a different, random array. The same seed value will also always generate the same random array, so we can later use it for other purposes like interpolation.
#
# `--truncation-psi`
#
# Truncation is a special argument of StyleGAN. Essentially values that are closer to 0 will be more real than numbers further away from 0. I generally recommend a value between `0.5` and `1.0`. `0.5` will give you pretty "realistic" results, while `1.0` is likely to give you "weirder" results.

# %%
# !pip install opensimplex
import opensimplex
# Out:
# Collecting opensimplex
#   Downloading opensimplex-0.4.2-py3-none-any.whl (17 kB)
# Collecting numpy>=1.20
#   Downloading numpy-1.21.5-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 28.6 MB/s
# Installing collected packages: numpy, opensimplex
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lucid 0.3.10 requires umap-learn, which is not installed.
# tensorflow 1.15.2 requires gast==0.2.2, but you have gast 0.4.0 which is incompatible.
# lucid 0.3.10 requires numpy<=1.19, but you have numpy 1.21.5 which is incompatible.
# yellowbrick 1.3.post1 requires numpy<1.20,>=1.16.0, but you have numpy 1.21.5 which is incompatible.
# kapre 0.3.7 requires tensorflow>=2.0.0, but you have tensorflow 1.15.2 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed numpy-1.21.5 opensimplex-0.4.2

# %%
import os 
os.listdir('/content/drive/MyDrive/stylegan2-colab/stylegan2/results/00001-pretrained') #network-snapshot-10000.pkl
# Out:
# ['network-snapshot-10000.pkl']

# %%
# !python run_generator.py generate-images --network=/content/drive/MyDrive/stylegan2-colab/stylegan2/results/00001-pretrained/network-snapshot-10000.pkl --seeds=0-1000 --truncation-psi=0.5
# Out:
# python3: can't open file 'run_generator.py': [Errno 2] No such file or directory

# %% [markdown]
# Let’s zip the generated files and download them.

# %%
# check the folder which has the images in it  - in this case it is 00004-generate-images
# !zip -r generated-0.7.zip /content/drive/MyDrive/stylegan2-colab/stylegan2/results/00004-generate-images
# Out:
# 	zip warning: name not matched: /content/drive/MyDrive/stylegan2-colab/stylegan2/results/00004-generate-images
#
# zip error: Nothing to do! (try: zip -r generated-0.7.zip . -i /content/drive/MyDrive/stylegan2-colab/stylegan2/results/00004-generate-images)

# %% [markdown]
# ##Interpolation

# %%
# !python run_generator.py generate-latent-walk --network=/content/drive/MyDrive/stylegan2-colab/stylegan2/results/00001-pretrained/network-snapshot-10000.pkl --seeds=0,3,10,13,17,38,42,43,46,48,55,63,67,69,85,88,92,97,98,99,117,119,124,137,139,141,146,152,156,160,173,177,180,189,191,195,198,203,205,212,220,221,228,230,247,267,271,290,292,293,297,300,301,302,306,309,316,318,319,321,324,332,338,340,364,365,371,393,396,427,435,450,458,459,465,468,469,471,487,493,497,498,499,505,516,521,523,525,542,543,548,573,576,577,588,593,597,621,622,627,632,637,657,694,695,704,705,707,712,713,724,726,737,739,752,761,771,779,780,789,797,0	 --frames 7192 --truncation-psi=0.5
# Out:
# python3: can't open file 'run_generator.py': [Errno 2] No such file or directory

# %%
#convert to video 
# !ffmpeg -r 24 -i /content/drive/MyDrive/stylegan2-colab/stylegan2/results/00005-generate-latent-walk/frame%05d.png -vcodec libx264 -pix_fmt yuv420p latent-walk-sectelev.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/content/drive/MyDrive/stylegan2-colab/stylegan2/results/00005-generate-latent-walk/frame%05d.png':
#   Duration: 00:04:50.40, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1024x1024, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55b3e78c7e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55b3e78c7e00] profile High, level 3.2
# [libx264 @ 0x55b3e78c7e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'latent-walk-sectelev.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1024x1024, q=-1--1, 24 fps, 12288 tbn, 24 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame= 7260 fps= 24 q=-1.0 Lsize=  108208kB time=00:05:02.37 bitrate=2931.6kbits/s speed=1.01x
# video:108127kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.075501%
# [libx264 @ 0x55b3e78c7e00] frame I:30    Avg QP:21.02  size: 75528
# [libx264 @ 0x55b3e78c7e00] frame P:2553  Avg QP:23.67  size: 30954
# [libx264 @ 0x55b3e78c7e00] frame B:4677  Avg QP:26.32  size:  6292
# [libx264 @ 0x55b3e78c7e00] consecutive B-frames: 13.6%  1.3%  1.1% 84.1%
# [libx264 @ 0x55b3e78c7e00] mb I  I16..4:  7.6% 75.4% 17.0%
# [libx264 @ 0x55b3e78c7e00] mb P  I16..4:  3.6% 17.7%  2.7%  P16..4: 43.9% 14.6%  7.4%  0.0%  0.0%    skip:10.2%
# [libx264 @ 0x55b3e78c7e00] mb B  I16..4:  0.3%  0.9%  0.1%  B16..8: 23.5%  2.6%  0.9%  direct: 6.2%  skip:65.6%  L0:33.3% L1:53.1% BI:13.6%
# [libx264 @ 0x55b3e78c7e00] 8x8 transform intra:73.5% inter:74.6%
# [libx264 @ 0x55b3e78c7e00] coded y,uvDC,uvAC intra: 67.0% 63.3% 12.6% inter: 22.3% 21.5% 0.1%
# [libx264 @ 0x55b3e78c7e00] i16 v,h,dc,p: 28% 16%  7% 49%
# [libx264 @ 0x55b3e78c7e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 11% 17%  7% 10% 12%  8% 10%  7%
# [libx264 @ 0x55b3e78c7e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20%  9% 12%  7% 15% 15%  9%  8%  5%
# [libx264 @ 0x55b3e78c7e00] i8c dc,h,v,p: 55% 16% 22%  7%
# [libx264 @ 0x55b3e78c7e00] Weighted P-Frames: Y:36.5% UV:21.4%
# [libx264 @ 0x55b3e78c7e00] ref P L0: 56.3% 27.3% 12.7%  3.0%  0.8%
# [libx264 @ 0x55b3e78c7e00] ref B L0: 95.0%  3.7%  1.3%
# [libx264 @ 0x55b3e78c7e00] ref B L1: 99.1%  0.9%
# [libx264 @ 0x55b3e78c7e00] kb/s:2928.16

# %%
# this is to remove the folder
#rm -r /content/drive/My Drive/stylegan2-colab-test/stylegan2/results/00002-stylegan2-birdaus-1gpu-config-f
# Out:
# rm: cannot remove '/content/drive/My': No such file or directory
# rm: cannot remove 'Drive/stylegan2-colab-test/stylegan2/results/00002-stylegan2-birdaus-1gpu-config-f': No such file or directory
